# %%
# %matplotlib inline

# %%
from mental_rotation import config
from mental_rotation.extra import BQ
import mental_rotation.extra.bq_c as bq_c

# %%
gamma = config.getfloat("bq", "gamma")
ntry = config.getint("bq", "ntry")
n_candidate = config.getint("bq", "n_candidate")
R_mean = config.getfloat("model", "R_mu")
R_var = 1. / config.getfloat("model", "R_kappa")

# %%
ns = 30

x = np.linspace(-8, 8, ns)
y = scipy.stats.norm.pdf(x, 0, 1)
bq = BQ(x, y, gamma, ntry, n_candidate, R_mean, R_var, s=0)
bq._fit_S()
bq.gp_S.params = (1, 1, 0)
bq._fit_log_S()
bq._fit_Dc()

N = np.logspace(np.log10(30), np.log10(300), 100)
# Out:
# INFO:mental_rotation.extra.bq:Fitting parameters for GP over S
# INFO:gp.gp:Best parameters: [ 0.18695101  1.31818502  0.        ]
# INFO:mental_rotation.extra.bq:Fitting w parameter for GP over S
# INFO:gp.gp:Best parameters: [ 0.18695101  1.20042684  0.        ]
# INFO:mental_rotation.extra.bq:Fitting parameters for GP over log(S)
# INFO:gp.gp:Best parameters: [ 0.69314718  1.          0.        ]
# INFO:mental_rotation.extra.bq:Fitting parameters for GP over Delta_c
# WARNING:gp.gp:MLII failed, p=[ 1.17290907  1.45479286]
# WARNING:gp.gp:MLII failed, p=[ 2.04869705  1.02266308]
# WARNING:gp.gp:MLII failed, p=[ 0.60154733  2.36872719]
# WARNING:gp.gp:MLII failed, p=[ 0.21522983  2.23917122]
# WARNING:gp.gp:MLII failed, p=[ 1.20614777  1.99907905]
# WARNING:gp.gp:MLII failed, p=[ 1.77681012  0.5728222 ]
# INFO:gp.gp:Best parameters: [ 0.59899607  0.51455301  0.        ]

# %%
xo = np.linspace(-10, 10, N[-1])
yo = scipy.stats.norm.pdf(xo, 0, 1)
plt.plot(xo, yo, 'k-')
plt.plot(xo, bq.S_mean(xo), 'r-')
plt.plot(bq.R, bq.S, 'ro')

# %%
calc = np.empty(bq.R.shape[0])
bq_c.int_K(
    calc, bq.R[:, None],
    bq.gp_S.K.h, np.array([bq.gp_S.K.w]),
    bq.R_mean, bq.R_cov)

approx = np.empty((N.size, bq.R.shape[0]))
for i, n in enumerate(N):
    xo = np.linspace(-10, 10, n)
    Kxxo = bq.gp_S.Kxxo(xo)
    p_xo = scipy.stats.norm.pdf(xo, bq.R_mean[0], np.sqrt(bq.R_cov[0, 0]))
    approx[i] = np.trapz(Kxxo * p_xo, xo)

# %%
plt.plot(N, np.abs(calc-approx).sum(axis=-1), lw=2, color='r')

# %%
print np.abs(calc - approx[-1]).max()
print approx[-1].sum(), calc.sum()
# Out:
# 0.000215428844705
# 1.70188394695 1.70216351243

# %%
plt.plot(approx[-1], lw=2)
plt.plot(calc, '--', lw=2)

# %%
calc = bq_c.int_int_K(
    1, bq.gp_S.K.h, np.array([bq.gp_S.K.w]),
    bq.R_mean, bq.R_cov)

approx = np.empty(N.size)
for i, n in enumerate(N):
    xo = np.linspace(-10, 10, n)
    Kxoxo = bq.gp_S.Kxoxo(xo)
    p_xo = scipy.stats.norm.pdf(xo, bq.R_mean[0], np.sqrt(bq.R_cov[0, 0]))
    approx[i] = np.trapz(np.trapz(Kxoxo * p_xo, xo) * p_xo, xo)

# %%
plt.plot(N, np.abs(calc-approx), lw=2, color='r')

# %%
print np.abs(calc - approx[-1]).max()
print approx[-1], calc
# Out:
# 0.000181367478797
# 0.0868749752763 0.0870563427551

# %%
calc = np.empty(ns)
bq_c.int_int_K1_K2(
    calc, bq.gp_log_S.x[:, None],
    bq.gp_S.K.h, np.array([bq.gp_S.K.w]),
    bq.gp_log_S.K.h, np.array([bq.gp_log_S.K.w]),
    bq.R_mean, bq.R_cov)

approx = np.empty((N.size, ns))
for i, n in enumerate(N):
    xo = np.linspace(-10, 10, n)
    K1xoxo = bq.gp_S.Kxoxo(xo)
    K2xxo = bq.gp_log_S.Kxxo(xo)
    p_xo = scipy.stats.norm.pdf(xo, bq.R_mean[0], np.sqrt(bq.R_cov[0, 0]))
    int1 = np.trapz(K1xoxo * K2xxo[:, :, None] * p_xo, xo)
    approx[i] = np.trapz(int1 * p_xo, xo)

# %%
plt.plot(N, np.abs(calc - approx).sum(axis=-1), lw=2, color='r')

# %%
print np.abs(calc - approx[-1]).max()
print approx[-1].sum(), calc.sum()
# Out:
# 7.29232017969e-06
# 0.0743023882896 0.074316392491

# %%
plt.plot(approx[-1], lw=2)
plt.plot(calc, '--', lw=2)

# %%
calc = np.empty((ns, ns))
bq_c.int_int_K1_K2_K1(
    calc, bq.gp_S.x[:, None],
    bq.gp_S.K.h, np.array([bq.gp_S.K.w]),
    bq.gp_log_S.K.h, np.array([bq.gp_log_S.K.w]),
    bq.R_mean, bq.R_cov)
    
approx = np.empty((N.size, ns, ns))
for i, n in enumerate(N):
    xo = np.linspace(-10, 10, n)
    K1xxo = bq.gp_S.Kxxo(xo)
    K2xoxo = bq.gp_log_S.Kxoxo(xo)
    p_xo = scipy.stats.norm.pdf(xo, bq.R_mean[0], np.sqrt(bq.R_cov[0, 0]))
    int1 = np.trapz(K1xxo[:, :, None] * K2xoxo * p_xo, xo)
    approx[i] = np.trapz(K1xxo[:, None] * int1[None, :] * p_xo, xo)

# %%
plt.plot(N, np.abs(calc - approx).sum(axis=-1).sum(axis=-1), lw=2, color='r')

# %%
print np.abs(calc - approx[-1]).max()
print approx[-1].sum(), calc.sum()
# Out:
# 0.00031282730102
# 0.133284477187 0.133022510848

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(approx[-1], cmap='gray', interpolation='nearest', vmin=0, vmax=0.002)
ax2.imshow(calc, cmap='gray', interpolation='nearest', vmin=0, vmax=0.002)

# %%
plt.plot(approx[-1, 20], lw=2)
plt.plot(calc[20], '--', lw=2)

# %%
calc = np.empty((ns, ns))
bq_c.int_K1_K2(
    calc, bq.gp_S.x[:, None], bq.gp_log_S.x[:, None],
    bq.gp_S.K.h, np.array([bq.gp_S.K.w]),
    bq.gp_log_S.K.h, np.array([bq.gp_log_S.K.w]),
    bq.R_mean, bq.R_cov)

approx = np.empty((N.size, ns, ns))
for i, n in enumerate(N):
    xo = np.linspace(-10, 10, n)

    K1xxo = bq.gp_S.Kxxo(xo)
    K2xxo = bq.gp_log_S.Kxxo(xo)
    p_xo = scipy.stats.norm.pdf(xo, bq.R_mean[0], np.sqrt(bq.R_cov[0, 0]))
    approx[i] = np.trapz(K1xxo[:, None] * K2xxo[None, :] * p_xo, xo)

# %%
plt.plot(N, np.abs(calc - approx).sum(axis=-1).sum(axis=-1), lw=2, color='r')

# %%
print np.abs(calc - approx[-1]).max()
print approx[-1].sum(), calc.sum()
# Out:
# 3.34441804164e-06
# 1.4505007877 1.45050660024

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(approx[-1], cmap='gray', interpolation='nearest', vmin=0, vmax=0.02)
ax2.imshow(calc, cmap='gray', interpolation='nearest', vmin=0, vmax=0.02)

# %%
plt.plot(approx[-1, 20], lw=2)
plt.plot(calc[20], '--', lw=2)

# %%
calc = np.empty((bq.R.shape[0], bq.R.shape[0], 1))
bq_c.int_K1_dK2(
    calc, bq.gp_S.x[:, None], bq.gp_log_S.x[:, None],
    bq.gp_S.K.h, np.array([bq.gp_S.K.w]),
    bq.gp_log_S.K.h, np.array([bq.gp_log_S.K.w]),
    bq.R_mean, bq.R_cov)

approx = np.empty((N.size, ns, ns, 1))
for i, n in enumerate(N):
    xo = np.linspace(-10, 10, n)

    K1xxo = bq.gp_S.Kxxo(xo)
    dK2xxo = bq.gp_log_S.K.dK_dw(bq.gp_log_S._x, xo)
    p_xo = scipy.stats.norm.pdf(xo, bq.R_mean[0], np.sqrt(bq.R_cov[0, 0]))
    approx[i] = np.trapz(
        K1xxo[None, :] * dK2xxo[:, None] * p_xo, xo)[..., None]

# %%
plt.plot(N, np.abs(calc - approx).sum(axis=-1).sum(axis=-1).sum(axis=-1), lw=2, color='r')

# %%
print np.abs(calc - approx[-1]).max()
print approx[-1].sum(), calc.sum()
# Out:
# 1.26689305919e-05
# -0.0318155735368 -0.0317890327802

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(approx[-1, :, :, 0], cmap='gray', interpolation='nearest', vmin=0, vmax=0.02)
ax2.imshow(calc[:, :, 0], cmap='gray', interpolation='nearest', vmin=0, vmax=0.02)

# %%
plt.plot(approx[-1, 20, :, 0], lw=2)
plt.plot(calc[20, :, 0], '--', lw=2)

# %%
calc = np.empty((bq.R.shape[0], 1))
bq_c.int_dK(
    calc, bq.R[:, None],
    bq.gp_S.K.h, np.array([bq.gp_S.K.w]),
    bq.R_mean, bq.R_cov)

approx = np.empty((N.size, ns, 1))
for i, n in enumerate(N):
    xo = np.linspace(-10, 10, n)

    dKxxo = bq.gp_S.K.dK_dw(bq.gp_S._x, xo)
    p_xo = scipy.stats.norm.pdf(xo, bq.R_mean[0], np.sqrt(bq.R_cov[0, 0]))
    approx[i] = np.trapz(dKxxo * p_xo, xo)[..., None]

# %%
plt.plot(N, np.abs(calc - approx).sum(axis=-1).sum(axis=-1), lw=2, color='r')

# %%
print np.abs(calc - approx[-1]).max()
print approx[-1].sum(), calc.sum()
# Out:
# 0.000941866878056
# -0.0327540976189 -0.0313238434534

# %%
plt.plot(approx[-1, :, 0], lw=2)
plt.plot(calc[:, 0], '--', lw=2)
