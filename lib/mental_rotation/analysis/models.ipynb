# %%
# %matplotlib inline

# %%
from mental_rotation.stimulus import Stimulus2D
from mental_rotation import config, STIM_PATH
from mental_rotation.model import gold_standard as gs
from mental_rotation.model import hill_climbing as hc
import pymc
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
X = Stimulus2D.load(STIM_PATH.joinpath("A", "000_120_0.json"))
Xa = X.copy_from_initial()
Xb = X.copy_from_vertices()

fig, (ax1, ax2) = plt.subplots(1, 2)
Xa.plot(ax1)
Xb.plot(ax2)

# %%
R_mu = config.getfloat("model", "R_mu")
R_kappa = config.getfloat("model", "R_kappa")
S_sigma = config.getfloat("model", "S_sigma")

# %%
reload(gs)
gs_model = gs.GoldStandardModel(Xa, Xb, R_mu, R_kappa, S_sigma)
gs_model.sample()
gs_model.integrate()
# Out:
# 2.8967512850677547e-06

# %%
fig, ax = plt.subplots()
gs_model.plot(ax)

# %%
reload(hc)
hc_model = hc.HillClimbingModel(Xa, Xb, R_mu, R_kappa, S_sigma)
hc_model.sample()
hc_model.integrate()
# Out:
# Halting at iteration  7  of  360
# 1.2939195780877059e-06

# %%
fig, ax = plt.subplots()
gs_model.plot(ax)
hc_model.plot(ax)
