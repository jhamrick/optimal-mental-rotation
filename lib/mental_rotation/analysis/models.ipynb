# %%
# %matplotlib inline

# %%
from mental_rotation.stimulus import Stimulus2D
from mental_rotation import config, STIM_PATH
from mental_rotation.model import GoldStandardModel, HillClimbingModel
import pymc
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
X = Stimulus2D.load(STIM_PATH.joinpath("A", "000_120_0.json"))
Xa = X.copy_from_initial()
Xb = X.copy_from_vertices()

fig, (ax1, ax2) = plt.subplots(1, 2)
Xa.plot(ax1)
Xb.plot(ax2)

# %%
R_mu = config.getfloat("model", "R_mu")
R_kappa = config.getfloat("model", "R_kappa")
S_sigma = config.getfloat("model", "S_sigma")

# %%
gs_model = GoldStandardModel(Xa, Xb, R_mu, R_kappa, S_sigma)
gs_model.sample()
gs_model.print_stats()
# Out:
# log Z = -3.948126
# log LH(h0) = -8.803787
# log LH(h1) = -8.350020
# log LH(h0) / LH(h1) = -0.453767
# --> ACCEPT hypothesis 1

# %%
fig, ax = plt.subplots()
gs_model.plot(ax)

# %%
hc_model = HillClimbingModel(Xa, Xb, R_mu, R_kappa, S_sigma)
hc_model.sample()
hc_model.print_stats()
# Out:
# Halting at iteration  7  of  360
# log Z = -4.754301
# log LH(h0) = -8.803787
# log LH(h1) = -9.156195
# log LH(h0) / LH(h1) = 0.352408
# --> REJECT hypothesis 1

# %%
fig, ax = plt.subplots()
gs_model.plot(ax)
hc_model.plot(ax)
