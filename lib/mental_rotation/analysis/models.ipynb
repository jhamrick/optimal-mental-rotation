# %%
# %matplotlib inline

# %%
from IPython.display import Image
from mental_rotation.stimulus import Stimulus2D
from mental_rotation import config, STIM_PATH, FIG_PATH, SEED
from mental_rotation.model import GoldStandardModel, HillClimbingModel
from mental_rotation.model import bayesian_quadrature_model as bq
import pymc
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
def seed():
    np.random.seed(SEED)

# %%
X = Stimulus2D.load(STIM_PATH.joinpath("D", "000_120_0.json"))
Xa = X.copy_from_initial()
Xb = X.copy_from_vertices()

fig, (ax1, ax2) = plt.subplots(1, 2)
Xa.plot(ax1)
Xb.plot(ax2)

# %%
seed()
gs_model = GoldStandardModel(Xa.vertices, Xb.vertices)
gs_model.sample()
gs_model.print_stats()
# Out:
# log LH(h0) = -9.001853
# log LH(h1) = -10.050903
# log LH(h0) / LH(h1) = 1.049050
# --> STOP and accept hypothesis 0 (same)

# %%
pymc.graph.graph(
    gs_model, 
    name="mental_rotation_model", 
    format="png", 
    path=FIG_PATH)

Image(FIG_PATH.joinpath("mental_rotation_model.png"))

# %%
fig, ax = plt.subplots()
gs_model.plot(ax)

# %%
seed()
hc_model = HillClimbingModel(Xa.vertices, Xb.vertices)
hc_model.sample()
hc_model.print_stats()
# Out:
# Halting at iteration  14  of  720
# log LH(h0) = -9.841169
# log LH(h1) = -10.547785
# log LH(h0) / LH(h1) = 0.706616
# --> STOP and accept hypothesis 0 (same)

# %%
fig, ax = plt.subplots()
gs_model.plot(ax)
hc_model.plot(ax)

# %%
reload(bq)
seed()
bq_model = bq.BayesianQuadratureModel(Xa.vertices, Xb.vertices)
bq_model.sample()
bq_model.print_stats()

# %%
fig, axes = plt.subplots(1, 3)
bq_model.plot(axes, f_S=gs_model.S)

# %%
print "E[Z] = %f" % bq_model.bq.Z_mean()
print "V(Z) = %f" % bq_model.bq.Z_var()
