# %%
# %matplotlib inline

# %%
from mental_rotation.stimulus import Stimulus2D
from mental_rotation import config, STIM_PATH, SEED
from mental_rotation.model import GoldStandardModel, HillClimbingModel
from mental_rotation.model import bayesian_quadrature as bq
import pymc
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
def seed():
    np.random.seed(SEED)

# %%
X = Stimulus2D.load(STIM_PATH.joinpath("A", "000_120_0.json"))
Xa = X.copy_from_initial()
Xb = X.copy_from_vertices()

fig, (ax1, ax2) = plt.subplots(1, 2)
Xa.plot(ax1)
Xb.plot(ax2)

# %%
seed()
gs_model = GoldStandardModel(Xa, Xb)
gs_model.sample()
gs_model.print_stats()
# Out:
# log Z = -3.876007
# log LH(h0) = -8.803787
# log LH(h1) = -8.277900
# log LH(h0) / LH(h1) = -0.525887
# --> ACCEPT hypothesis 1

# %%
fig, ax = plt.subplots()
gs_model.plot(ax)

# %%
seed()
hc_model = HillClimbingModel(Xa, Xb)
hc_model.sample()
hc_model.print_stats()
# Out:
# Halting at iteration  8  of  360
# log Z = -4.837922
# log LH(h0) = -8.803787
# log LH(h1) = -9.239816
# log LH(h0) / LH(h1) = 0.436029
# --> REJECT hypothesis 1

# %%
fig, ax = plt.subplots()
gs_model.plot(ax)
hc_model.plot(ax)

# %%
reload(bq)
seed()
bq_model = bq.BayesianQuadratureModel(Xa, Xb)
bq_model.sample()
bq_model.print_stats()
# Out:
# INFO:mental_rotation.extra.bq:Fitting likelihood
# INFO:mental_rotation.extra.bq:Fitting parameters for GP over S
# INFO:gp.gp:Best parameters: [ 0.01798398  1.35546364  0.        ]
# INFO:mental_rotation.extra.bq:Fitting w parameter for GP over S
# INFO:gp.gp:Best parameters: [  1.79839764e-02   2.45521713e+02   0.00000000e+00]
# INFO:mental_rotation.extra.bq:Fitting parameters for GP over log(S)
# INFO:gp.gp:Best parameters: [  1.78241777e-02   2.41348742e+02   0.00000000e+00]
# INFO:mental_rotation.extra.bq:Fitting parameters for GP over Delta_c
# INFO:gp.gp:Best parameters: [ 0.00247229  0.10467972  0.        ]
# INFO:mental_rotation.extra.bq:Fitting likelihood
# INFO:mental_rotation.extra.bq:Fitting parameters for GP over S
# WARNING:gp.gp:MLII failed, p=[ 0.70763064  1.28139881]
# WARNING:gp.gp:MLII failed, p=[ 1.93377531  1.12975373]
# WARNING:gp.gp:MLII failed, p=[ 1.67943253  2.10335087]
# INFO:gp.gp:Best parameters: [ 0.06278818  0.39730737  0.        ]
# INFO:mental_rotation.extra.bq:Fitting w parameter for GP over S
# WARNING:gp.gp:MLII failed, p=[ 1.70021149]
# INFO:gp.gp:Best parameters: [ 0.06278818  0.39730732  0.        ]
# INFO:mental_rotation.extra.bq:Fitting parameters for GP over log(S)
# INFO:gp.gp:Best parameters: [ 0.06089581  0.39730732  0.        ]
# INFO:mental_rotation.extra.bq:Fitting parameters for GP over Delta_c
# WARNING:gp.gp:MLII failed, p=[ 0.91524126  0.70698151]
# WARNING:gp.gp:MLII failed, p=[ 1.39161887  1.41691051]
# WARNING:gp.gp:MLII failed, p=[ 1.19365823  0.89120428]
# WARNING:gp.gp:MLII failed, p=[ 0.16728253  1.52994745]
# WARNING:gp.gp:MLII failed, p=[ 1.64683158  0.75676284]
# WARNING:gp.gp:MLII failed, p=[ 0.67699969  1.24745356]
# WARNING:gp.gp:MLII failed, p=[ 0.00608022  0.61293503]
# INFO:gp.gp:Best parameters: [ 0.57182228  0.33157976  0.        ]
# target = 2.11433886002
# R = 0.174532925199
# R = 0.349065850399
# R = 0.523598775598
# R = 0.698131700798
# R = 0.872664625997
# R = 1.0471975512
# R = 1.2217304764
# R = 1.3962634016
# R = 1.57079632679
# R = 1.74532925199
# R = 1.91986217719
# Z = 0.014010 [-0.014547, 0.042566]
# /Users/jhamrick/project/optimal-mental-rotation/lib/mental_rotation/extra/bq.py:213: UserWarning: E_m_l_m_del = -5.70129900888e-05
#   self.R_mean, self.R_cov, self.gamma)
# /Users/jhamrick/project/optimal-mental-rotation/lib/mental_rotation/extra/bq.py:213: UserWarning: E_m_del = -0.000393143035188
#   self.R_mean, self.R_cov, self.gamma)
# /Users/jhamrick/project/optimal-mental-rotation/lib/mental_rotation/model/bayesian_quadrature.py:133: RuntimeWarning: invalid value encountered in log
#   return np.log(self.Z)
# INFO:mental_rotation.extra.bq:Fitting likelihood
# INFO:mental_rotation.extra.bq:Fitting parameters for GP over S
# WARNING:gp.gp:MLII failed, p=[ 0.47689314  1.63319357]
# WARNING:gp.gp:MLII failed, p=[ 0.108381    1.28487056]
# WARNING:gp.gp:MLII failed, p=[ 0.4557965  1.1967655]
# INFO:gp.gp:Best parameters: [ 0.46339749  0.50058379  0.        ]
# INFO:mental_rotation.extra.bq:Fitting w parameter for GP over S
# WARNING:gp.gp:MLII failed, p=[ 1.48351778]
# WARNING:gp.gp:MLII failed, p=[ 0.48915052]
# WARNING:gp.gp:MLII failed, p=[ 2.14791606]
# INFO:gp.gp:Best parameters: [ 0.46339749  0.48915055  0.        ]
# INFO:mental_rotation.extra.bq:Fitting parameters for GP over log(S)
# INFO:gp.gp:Best parameters: [ 0.38076078  0.48915055  0.        ]
# INFO:mental_rotation.extra.bq:Fitting parameters for GP over Delta_c
# WARNING:gp.gp:MLII failed, p=[ 1.36146895  1.28060758]
# WARNING:gp.gp:MLII failed, p=[ 1.3460483   1.07622414]
# WARNING:gp.gp:MLII failed, p=[ 0.06143661  1.27643148]
# WARNING:gp.gp:MLII failed, p=[ 0.73284477  1.30187737]
# WARNING:gp.gp:MLII failed, p=[ 2.18929137  1.00787329]
# WARNING:gp.gp:MLII failed, p=[ 0.09344722  0.58661228]
# WARNING:gp.gp:MLII failed, p=[ 0.17233088  1.12008181]
# WARNING:gp.gp:MLII failed, p=[ 0.8165938   1.37015867]
# WARNING:gp.gp:MLII failed, p=[ 0.44079184  0.5935366 ]
# INFO:gp.gp:Best parameters: [ 1.33959047  0.12879793  0.        ]
# log LH(h0) = -8.803787
# log LH(h1) = -8.669891 [nan, -7.558584]
# LH(h0) / LH(h1) = -0.133896 [nan, -1.245203]
# --> UNDECIDED
# target = -2.26613353626
# INFO:mental_rotation.extra.bq:Fitting likelihood
# INFO:mental_rotation.extra.bq:Fitting parameters for GP over S
# WARNING:gp.gp:MLII failed, p=[ 0.65089659  1.62770844]
# INFO:gp.gp:Best parameters: [ 0.057314    0.37501644  0.        ]
# INFO:mental_rotation.extra.bq:Fitting w parameter for GP over S
# WARNING:gp.gp:MLII failed, p=[ 1.16230395]
# WARNING:gp.gp:MLII failed, p=[ 1.39288994]
# WARNING:gp.gp:MLII failed, p=[ 1.49864849]
# WARNING:gp.gp:MLII failed, p=[ 0.99965368]
# INFO:gp.gp:Best parameters: [ 0.057314    0.36249617  0.        ]
# INFO:mental_rotation.extra.bq:Fitting parameters for GP over log(S)
# INFO:gp.gp:Best parameters: [ 0.05573173  0.36249617  0.        ]
# INFO:mental_rotation.extra.bq:Fitting parameters for GP over Delta_c
# WARNING:gp.gp:MLII failed, p=[ 0.43635487  1.01525377]
# WARNING:gp.gp:MLII failed, p=[ 2.31557019  1.09428519]
# WARNING:gp.gp:MLII failed, p=[ 0.68433578  2.80054323]
# WARNING:gp.gp:MLII failed, p=[ 2.29158287  1.06421494]
# WARNING:gp.gp:MLII failed, p=[ 0.29317063  1.17329352]
# WARNING:gp.gp:MLII failed, p=[ 1.77561979  0.87861042]
# INFO:gp.gp:Best parameters: [ 0.48068403  0.46585792  0.        ]
# R = 2.26892802759
# Z = 0.011463 [-0.013743, 0.036669]
# log LH(h0) = -8.803787
# log LH(h1) = -8.870527 [nan, -7.707725]
# LH(h0) / LH(h1) = 0.066740 [nan, -1.096062]
# --> UNDECIDED
# Z = 0.011463 [-0.013743, 0.036669]
# log LH(h0) = -8.803787
# log LH(h1) = -8.870527 [nan, -7.707725]
# LH(h0) / LH(h1) = 0.066740 [nan, -1.096062]
# --> UNDECIDED
# /Users/jhamrick/project/optimal-mental-rotation/lib/mental_rotation/extra/bq.py:213: UserWarning: E_m_del = -0.00201315821703
#   self.R_mean, self.R_cov, self.gamma)

# %%
fig, axes = plt.subplots(2, 2)
gs_model.plot(axes[0, 0])
gs_model.plot(axes[0, 1])
gs_model.plot(axes[1, 0])
bq_model.plot(axes)

# %%
print "E[Z] = %f" % bq_model.bq.Z_mean()
print "V(Z) = %f" % bq_model.bq.Z_var()
# Out:
# E[Z] = 0.011463
# V(Z) = 0.000165
